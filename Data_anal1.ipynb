# %%
import pandas as pd
import numpy as np
import os
import urllib
from sklearn.metrics import mean_absolute_error
# %matplotlib inline

# %%
url = 'https://covid19.who.int/WHO-COVID-19-global-data.csv'
file_path = os.path.join('data', 'covid')

# %%
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path, 'WHO-covid-19-global-data.csv')
urllib.request.urlretrieve(url, csv_path)
# Out:
# ('data\\covid\\WHO-covid-19-global-data.csv',
#  <http.client.HTTPMessage at 0x2a1a0e59d88>)

# %%
df = pd.read_csv(csv_path)

# %%
print(df)
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-02-24           AF  Afghanistan       EMRO          5
# 1        2020-02-25           AF  Afghanistan       EMRO          0
# 2        2020-02-26           AF  Afghanistan       EMRO          0
# 3        2020-02-27           AF  Afghanistan       EMRO          0
# 4        2020-02-28           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 31764    2020-07-26           ZW     Zimbabwe       AFRO        138
# 31765    2020-07-27           ZW     Zimbabwe       AFRO         78
# 31766    2020-07-28           ZW     Zimbabwe       AFRO        192
# 31767    2020-07-29           ZW     Zimbabwe       AFRO        113
# 31768    2020-07-30           ZW     Zimbabwe       AFRO         62
#
#        Cumulative_cases  New_deaths  Cumulative_deaths   Pct_cases
# 0                     5           0                  0  100.000000
# ...

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=31769, step=1)

# %%
df_cols = df.columns
df_cols
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([    0,     1,     2, ..., 31766, 31767, 31768], dtype=int64)

# %%
df.dtypes
# Out:
# Date_reported         object
#  Country_code         object
#  Country              object
#  WHO_region           object
#  New_cases             int64
#  Cumulative_cases      int64
#  New_deaths            int64
#  Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (31769, 8)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-02-24           AF  Afghanistan       EMRO          5
# 1        2020-02-25           AF  Afghanistan       EMRO          0
# 2        2020-02-26           AF  Afghanistan       EMRO          0
# 3        2020-02-27           AF  Afghanistan       EMRO          0
# 4        2020-02-28           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 31764    2020-07-26           ZW     Zimbabwe       AFRO        138
# 31765    2020-07-27           ZW     Zimbabwe       AFRO         78
# 31766    2020-07-28           ZW     Zimbabwe       AFRO        192
# 31767    2020-07-29           ZW     Zimbabwe       AFRO        113
# 31768    2020-07-30           ZW     Zimbabwe       AFRO         62
#
#        Cumulative_cases  New_deaths  Cumulative_deaths   Pct_cases
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-02-24           AF  Afghanistan       EMRO          5
# 1        2020-02-25           AF  Afghanistan       EMRO          0
# 2        2020-02-26           AF  Afghanistan       EMRO          0
# 3        2020-02-27           AF  Afghanistan       EMRO          0
# 4        2020-02-28           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 31764    2020-07-26           ZW     Zimbabwe       AFRO        138
# 31765    2020-07-27           ZW     Zimbabwe       AFRO         78
# 31766    2020-07-28           ZW     Zimbabwe       AFRO        192
# 31767    2020-07-29           ZW     Zimbabwe       AFRO        113
# 31768    2020-07-30           ZW     Zimbabwe       AFRO         62
#
#        Cumulative_cases  New_deaths  Cumulative_deaths   Pct_cases
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-02-24           AF  Afghanistan       EMRO          5
# 1        2020-02-25           AF  Afghanistan       EMRO          0
# 2        2020-02-26           AF  Afghanistan       EMRO          0
# 3        2020-02-27           AF  Afghanistan       EMRO          0
# 4        2020-02-28           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 31764    2020-07-26           ZW     Zimbabwe       AFRO        138
# 31765    2020-07-27           ZW     Zimbabwe       AFRO         78
# 31766    2020-07-28           ZW     Zimbabwe       AFRO        192
# 31767    2020-07-29           ZW     Zimbabwe       AFRO        113
# 31768    2020-07-30           ZW     Zimbabwe       AFRO         62
#
#        Cumulative_cases  New_deaths  Cumulative_deaths   Pct_cases
# ...

# %%
df[' Country']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 31764       Zimbabwe
# 31765       Zimbabwe
# 31766       Zimbabwe
# 31767       Zimbabwe
# 31768       Zimbabwe
# Name:  Country, Length: 31769, dtype: object

# %%
df[' Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Costa Rica', 'Côte d’Ivoire', 'Croatia',
#        'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df.columns = [col.strip() for col in df.columns]

# %%
df.Country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 31764       Zimbabwe
# 31765       Zimbabwe
# 31766       Zimbabwe
# 31767       Zimbabwe
# 31768       Zimbabwe
# Name: Country, Length: 31769, dtype: object

# %%
df.loc[1:4, 'Country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8, ['Country', 'New_cases']]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country == 'United States of America'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31764    False
# 31765    False
# 31766    False
# 31767    False
# 31768    False
# Name: Country, Length: 31769, dtype: bool

# %%
df[df.Country == 'United States of America']
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 30447    2020-01-20           US  United States of America       AMRO
# 30448    2020-01-21           US  United States of America       AMRO
# 30449    2020-01-22           US  United States of America       AMRO
# 30450    2020-01-23           US  United States of America       AMRO
# 30451    2020-01-24           US  United States of America       AMRO
# ...             ...          ...                       ...        ...
# 30636    2020-07-27           US  United States of America       AMRO
# 30637    2020-07-28           US  United States of America       AMRO
# 30638    2020-07-29           US  United States of America       AMRO
# 30639    2020-07-30           US  United States of America       AMRO
# 30640    2020-07-31           US  United States of America       AMRO
#
#        New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df[df.New_deaths > 1000]
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 4026     2020-05-21           BR                    Brazil       AMRO
# 4028     2020-05-23           BR                    Brazil       AMRO
# 4029     2020-05-24           BR                    Brazil       AMRO
# 4033     2020-05-28           BR                    Brazil       AMRO
# 4034     2020-05-29           BR                    Brazil       AMRO
# ...             ...          ...                       ...        ...
# 30634    2020-07-25           US  United States of America       AMRO
# 30635    2020-07-26           US  United States of America       AMRO
# 30638    2020-07-29           US  United States of America       AMRO
# 30639    2020-07-30           US  United States of America       AMRO
# 30640    2020-07-31           US  United States of America       AMRO
#
#        New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df.loc[(df.New_deaths > 6000) & (df.Country_code == 'US'), 
       ['Date_reported', 'New_cases', 'New_deaths', 'Cumulative_deaths']]
# Out:
#       Date_reported  New_cases  New_deaths  Cumulative_deaths
# 30535    2020-04-17      28711        6409              32280

# %%
df.loc[df.Country_code == 'US', ['New_cases', 'Date_reported']].max()
# Out:
# New_cases             74354
# Date_reported    2020-07-31
# dtype: object

# %%
df.loc[df.Country_code == 'US', ['New_cases', 'Date_reported']].min()
# Out:
# New_cases                 0
# Date_reported    2020-01-20
# dtype: object

# %%
df.loc[df.New_deaths.idxmax(), ['Date_reported', 'New_cases', 'New_deaths', 'Cumulative_deaths']]
# Out:
# Date_reported        2020-04-17
# New_cases                 28711
# New_deaths                 6409
# Cumulative_deaths         32280
# Name: 30535, dtype: object

# %%
df[df.New_deaths < 0]
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 1583     2020-06-04           AU                 Australia       WPRO
# 4639     2020-07-13           BF              Burkina Faso       AFRO
# 6531     2020-06-09           CG                     Congo       AFRO
# 7375     2020-05-14           CY                    Cyprus       EURO
# 7532     2020-05-19           CZ                   Czechia       EURO
# 7579     2020-07-05           CZ                   Czechia       EURO
# 7580     2020-07-06           CZ                   Czechia       EURO
# 7823     2020-05-13           DK                   Denmark       EURO
# 10183    2020-05-20           FR                    France       EURO
# 11984    2020-07-06           GP                Guadeloupe       AMRO
# 12198    2020-05-05           GT                 Guatemala       AMRO
# 12542    2020-07-04           GN                    Guinea       AFRO
# ...

# %%
df['Pct_cases'] = (df['New_cases'] / df['Cumulative_cases'])*100

# %%
df
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-02-24           AF  Afghanistan       EMRO          5
# 1        2020-02-25           AF  Afghanistan       EMRO          0
# 2        2020-02-26           AF  Afghanistan       EMRO          0
# 3        2020-02-27           AF  Afghanistan       EMRO          0
# 4        2020-02-28           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 31764    2020-07-26           ZW     Zimbabwe       AFRO        138
# 31765    2020-07-27           ZW     Zimbabwe       AFRO         78
# 31766    2020-07-28           ZW     Zimbabwe       AFRO        192
# 31767    2020-07-29           ZW     Zimbabwe       AFRO        113
# 31768    2020-07-30           ZW     Zimbabwe       AFRO         62
#
#        Cumulative_cases  New_deaths  Cumulative_deaths   Pct_cases
# 0                     5           0                  0  100.000000
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df_ger = df[df.Country == 'Germany']
y = df_ger.New_cases
needed_columns =['Cumulative_cases', 'New_deaths']
X = df_ger[needed_columns]
model = DecisionTreeRegressor()
model.fit(X, y)

print("First in-sample predictions:", model.predict(X.head(n=20)))
print("Actual target values:", y.head(n=20).tolist())
# Out:
# First in-sample predictions: [2.66666667 2.66666667 2.66666667 3.         1.         1.
#  1.         1.         1.         1.         0.25       0.25
#  0.25       0.25       0.14285714 0.14285714 0.14285714 0.14285714
#  0.14285714 0.14285714]
# Actual target values: [8, 0, 0, 3, 1, 2, 0, 2, 0, 1, 1, 0, 0, 0, 2, 0, 0, 0, 0, 0]

# %%
from sklearn.model_selection import train_test_split
# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)
